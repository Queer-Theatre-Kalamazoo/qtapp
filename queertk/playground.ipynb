# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from queertk.blueprints.common.models import Season
from sqlalchemy import select
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from queertk.blueprints.common.models import Credit
from queertk.blueprints.artist.models import Artist
from queertk.blueprints.production.models import Production

db_conn_string = 'mysql+mysqlconnector://f2u1tc92sd26:pscale_pw_6ULHy_FyYQgeNl2bNImqFPrWxOSJcFCnDFgdH2v0_rE@pylkzqxt5vhc.us-east-1.psdb.cloud/qtdb'
engine = create_engine(db_conn_string, future=True)
Session = sessionmaker(engine, future=True)

# %%
# Add "Test Season"
with Session.begin() as session:
    newseason = Season(description = 'Test Season', slug = 'test-season')
    session.add(newseason)

# %%
# Delete "Test Season"
with Session.begin() as session:
    season = session.query(Season).where(Season.description == 'Test Season').delete()

# %%
# Select season and print column values
with Session.begin() as session:
    result = session.execute(select(Season).where(Season.season_id == 1)).scalars().one()
    print(result.description + ' ' + result.slug)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/queertk-wHVNzSWm-py3.10/lib64/python3.10/site-packages/mysql/connector/connection_cext.py:236, in CMySQLConnection._open_connection(self)
#     <a href='file:///home/hazel/.cache/pypoetry/virtualenvs/queertk-wHVNzSWm-py3.10/lib64/python3.10/site-packages/mysql/connector/connection_cext.py?line=234'>235</a> try:
# --> <a href='file:///home/hazel/.cache/pypoetry/virtualenvs/queertk-wHVNzSWm-py3.10/lib64/python3.10/site-packages/mysql/connector/connection_cext.py?line=235'>236</a>     self._cmysql.connect(**cnx_kwargs)
#     <a href='file:///home/hazel/.cache/pypoetry/virtualenvs/queertk-wHVNzSWm-py3.10/lib64/python3.10/site-packages/mysql/connector/connection_cext.py?line=236'>237</a>     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# ...

# %%
with Session.begin() as session:
    artist = session.execute(select(Artist).where(Artist.artist_id == 1)).scalars().one()

    credits_query = select(Credit.role, Production.description, Production.production_id, Production.slug, Artist.artist_id).\
        where(Credit.artist_id == artist.artist_id).\
        join(Production, Production.production_id == Credit.production_id).\
        join(Artist, Artist.artist_id == artist.artist_id)
        
    credits = session.execute(credits_query).all()

    print(artist.artist_name, credits[1].role, credits[1].description)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/queertk-wHVNzSWm-py3.10/lib64/python3.10/site-packages/sqlalchemy/engine/base.py:1719, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///home/hazel/.cache/pypoetry/virtualenvs/queertk-wHVNzSWm-py3.10/lib64/python3.10/site-packages/sqlalchemy/engine/base.py?line=1716'>1717</a>         conn = self._revalidate_connection()
# -> <a href='file:///home/hazel/.cache/pypoetry/virtualenvs/queertk-wHVNzSWm-py3.10/lib64/python3.10/site-packages/sqlalchemy/engine/base.py?line=1718'>1719</a>     context = constructor(
# ...
